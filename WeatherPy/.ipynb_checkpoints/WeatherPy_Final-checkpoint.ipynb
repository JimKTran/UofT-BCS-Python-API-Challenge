# %% [markdown]
# ## WeatherPy Main Workfile

# %% [markdown]
# ### Initial identification

# %%
#!pip install arrow # this module is to get now() date

# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import arrow
from scipy.stats import linregress
import scipy.stats as sts
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

api_key = weather_api_key
#print(api_key)
len(cities)
# Out:
# 649

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# parameters

url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'
query_url = f'{url}appid={api_key}&units={units}&q='

# %%
# list names for dataframe
city_name = []
cloudiness = []
dates = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

# %%
# counters to store record counts and sets of 50 counts
record_count = 0
set_count = 1

# %%
# loop through list of random cities

print(f'Beginning Data Retrieval')
print('-------------------------------')

for index, city in enumerate(cities):
    
    #time.sleep(1) # Add a one second interval between queries to stay within API query limits   

    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        if record_count > 49:
            record_count = 0
            set_count += 1
        else:
            record_count += 1

        print(f"Processing Record {record_count} of Set {set_count} | {city}")
  
    except(KeyError, IndexError):
        
        print("City not found. Skipping...")
        
print('-------------------------------')
print('Data Retrieval Complete ')
print('-------------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | araouane
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | nowy tomysl
# Processing Record 4 of Set 1 | paracuru
# Processing Record 5 of Set 1 | leningradskiy
# Processing Record 6 of Set 1 | swan hill
# City not found. Skipping...
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | hokitika
# Processing Record 10 of Set 1 | baraboo
# Processing Record 11 of Set 1 | sargodha
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | smithers
# Processing Record 14 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | salta
# Processing Record 18 of Set 1 | northam
# Processing Record 19 of Set 1 | palmer
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | sembe
# Processing Record 23 of Set 1 | helong
# City not found. Skipping...
# Processing Record 24 of Set 1 | te anau
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | saint-pierre
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | souillac
# Processing Record 30 of Set 1 | le mars
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 33 of Set 1 | alofi
# Processing Record 34 of Set 1 | matara
# Processing Record 35 of Set 1 | coquimbo
# Processing Record 36 of Set 1 | sorland
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | comodoro rivadavia
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | constitucion
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | mehamn
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | inongo
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | saint-francois
# Processing Record 48 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 49 of Set 1 | praya
# Processing Record 50 of Set 1 | san patricio
# Processing Record 0 of Set 2 | jiazi
# Processing Record 1 of Set 2 | russell
# Processing Record 2 of Set 2 | grand gaube
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | viedma
# Processing Record 5 of Set 2 | baghdad
# Processing Record 6 of Set 2 | yokadouma
# Processing Record 7 of Set 2 | benjamin constant
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | tamale
# Processing Record 10 of Set 2 | ghanzi
# Processing Record 11 of Set 2 | gizo
# Processing Record 12 of Set 2 | namibe
# Processing Record 13 of Set 2 | makakilo city
# Processing Record 14 of Set 2 | sabha
# Processing Record 15 of Set 2 | una
# Processing Record 16 of Set 2 | ilebo
# Processing Record 17 of Set 2 | sukumo
# Processing Record 18 of Set 2 | rio grande
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | codrington
# City not found. Skipping...
# Processing Record 21 of Set 2 | lavrentiya
# Processing Record 22 of Set 2 | mikhaylovsk
# Processing Record 23 of Set 2 | onokhoy
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | nemuro
# Processing Record 26 of Set 2 | barreiras
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | katsuura
# City not found. Skipping...
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | raver
# Processing Record 31 of Set 2 | dunedin
# Processing Record 32 of Set 2 | sambava
# City not found. Skipping...
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | vostok
# Processing Record 35 of Set 2 | dikson
# City not found. Skipping...
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | mhlume
# Processing Record 38 of Set 2 | puerto ayora
# Processing Record 39 of Set 2 | berlevag
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | vieques
# Processing Record 42 of Set 2 | braintree
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | poum
# City not found. Skipping...
# Processing Record 46 of Set 2 | kirakira
# Processing Record 47 of Set 2 | hambantota
# Processing Record 48 of Set 2 | pangnirtung
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 0 of Set 3 | eirunepe
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | sao borja
# Processing Record 3 of Set 3 | cabadiangan
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | charters towers
# City not found. Skipping...
# Processing Record 6 of Set 3 | darhan
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | colborne
# Processing Record 10 of Set 3 | lethem
# Processing Record 11 of Set 3 | aquiraz
# Processing Record 12 of Set 3 | nioro
# Processing Record 13 of Set 3 | zyryanka
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | victoria
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | bedele
# Processing Record 18 of Set 3 | ambulu
# Processing Record 19 of Set 3 | san vicente
# City not found. Skipping...
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | qeshm
# Processing Record 22 of Set 3 | aykhal
# Processing Record 23 of Set 3 | svetlogorsk
# Processing Record 24 of Set 3 | hobart
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | touros
# Processing Record 27 of Set 3 | ambilobe
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | bundaberg
# Processing Record 30 of Set 3 | nome
# Processing Record 31 of Set 3 | birjand
# Processing Record 32 of Set 3 | murchison
# Processing Record 33 of Set 3 | rosarito
# City not found. Skipping...
# Processing Record 34 of Set 3 | lorengau
# City not found. Skipping...
# Processing Record 35 of Set 3 | wattegama
# Processing Record 36 of Set 3 | nuevitas
# Processing Record 37 of Set 3 | apen
# Processing Record 38 of Set 3 | diffa
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | urubamba
# Processing Record 41 of Set 3 | mattru
# Processing Record 42 of Set 3 | kisangani
# Processing Record 43 of Set 3 | kamaishi
# Processing Record 44 of Set 3 | bredasdorp
# City not found. Skipping...
# Processing Record 45 of Set 3 | lieksa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 3 | sao filipe
# City not found. Skipping...
# Processing Record 47 of Set 3 | acapulco
# Processing Record 48 of Set 3 | bonfim
# Processing Record 49 of Set 3 | geraldton
# Processing Record 50 of Set 3 | tuktoyaktuk
# Processing Record 0 of Set 4 | isangel
# Processing Record 1 of Set 4 | niquero
# Processing Record 2 of Set 4 | tashtyp
# Processing Record 3 of Set 4 | raudeberg
# Processing Record 4 of Set 4 | coruripe
# Processing Record 5 of Set 4 | bend
# Processing Record 6 of Set 4 | haverfordwest
# Processing Record 7 of Set 4 | omaruru
# Processing Record 8 of Set 4 | ajaccio
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | maceio
# Processing Record 11 of Set 4 | tchollire
# Processing Record 12 of Set 4 | mao
# Processing Record 13 of Set 4 | indramayu
# Processing Record 14 of Set 4 | quatre cocos
# Processing Record 15 of Set 4 | kulhudhuffushi
# Processing Record 16 of Set 4 | linda
# Processing Record 17 of Set 4 | santa isabel do rio negro
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | esperance
# Processing Record 20 of Set 4 | ponnani
# Processing Record 21 of Set 4 | dhidhdhoo
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | tiksi
# Processing Record 24 of Set 4 | bandar
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | bontang
# Processing Record 27 of Set 4 | weatherford
# Processing Record 28 of Set 4 | meulaboh
# Processing Record 29 of Set 4 | mount gambier
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | lyman
# Processing Record 32 of Set 4 | skjervoy
# Processing Record 33 of Set 4 | hamilton
# Processing Record 34 of Set 4 | namatanai
# Processing Record 35 of Set 4 | burnie
# Processing Record 36 of Set 4 | chicama
# Processing Record 37 of Set 4 | seoul
# Processing Record 38 of Set 4 | clyde river
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | mayo
# City not found. Skipping...
# Processing Record 41 of Set 4 | lebu
# Processing Record 42 of Set 4 | stromness
# Processing Record 43 of Set 4 | abnub
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | takoradi
# Processing Record 46 of Set 4 | pytalovo
# Processing Record 47 of Set 4 | ixtapa
# Processing Record 48 of Set 4 | nurota
# Processing Record 49 of Set 4 | camacha
# Processing Record 50 of Set 4 | lagos
# Processing Record 0 of Set 5 | ponta do sol
# City not found. Skipping...
# Processing Record 1 of Set 5 | lockport
# City not found. Skipping...
# Processing Record 2 of Set 5 | ukiah
# Processing Record 3 of Set 5 | oktyabrskiy
# Processing Record 4 of Set 5 | jumla
# City not found. Skipping...
# Processing Record 5 of Set 5 | ambon
# Processing Record 6 of Set 5 | biak
# Processing Record 7 of Set 5 | broome
# Processing Record 8 of Set 5 | santo tomas
# Processing Record 9 of Set 5 | yerbogachen
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | bakel
# Processing Record 12 of Set 5 | polunochnoye
# City not found. Skipping...
# Processing Record 13 of Set 5 | havre-saint-pierre
# Processing Record 14 of Set 5 | severo-kurilsk
# Processing Record 15 of Set 5 | abasolo
# Processing Record 16 of Set 5 | ahipara
# Processing Record 17 of Set 5 | santa isabel
# Processing Record 18 of Set 5 | sao joao da barra
# Processing Record 19 of Set 5 | saedinenie
# Processing Record 20 of Set 5 | seaca
# Processing Record 21 of Set 5 | bredy
# Processing Record 22 of Set 5 | miri
# Processing Record 23 of Set 5 | klaksvik
# Processing Record 24 of Set 5 | hurricane
# Processing Record 25 of Set 5 | arman
# Processing Record 26 of Set 5 | asau
# Processing Record 27 of Set 5 | bodden town
# Processing Record 28 of Set 5 | butaritari
# Processing Record 29 of Set 5 | tondano
# Processing Record 30 of Set 5 | yulara
# Processing Record 31 of Set 5 | petropavl
# Processing Record 32 of Set 5 | nosy varika
# Processing Record 33 of Set 5 | fairbanks
# Processing Record 34 of Set 5 | port blair
# Processing Record 35 of Set 5 | taltal
# Processing Record 36 of Set 5 | vestmannaeyjar
# Processing Record 37 of Set 5 | mogadishu
# Processing Record 38 of Set 5 | orocue
# Processing Record 39 of Set 5 | hirara
# Processing Record 40 of Set 5 | nhulunbuy
# Processing Record 41 of Set 5 | tiassale
# Processing Record 42 of Set 5 | avera
# City not found. Skipping...
# Processing Record 43 of Set 5 | seminole
# Processing Record 44 of Set 5 | sioux lookout
# Processing Record 45 of Set 5 | lata
# Processing Record 46 of Set 5 | saint anthony
# Processing Record 47 of Set 5 | college
# Processing Record 48 of Set 5 | khatanga
# City not found. Skipping...
# Processing Record 49 of Set 5 | tokur
# Processing Record 50 of Set 5 | manadhoo
# Processing Record 0 of Set 6 | munsingen
# Processing Record 1 of Set 6 | karpathos
# Processing Record 2 of Set 6 | cascais
# Processing Record 3 of Set 6 | korla
# Processing Record 4 of Set 6 | saint simons
# Processing Record 5 of Set 6 | shingu
# Processing Record 6 of Set 6 | kununurra
# Processing Record 7 of Set 6 | sola
# Processing Record 8 of Set 6 | longyearbyen
# Processing Record 9 of Set 6 | tombouctou
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | hualmay
# Processing Record 12 of Set 6 | honningsvag
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | mantua
# Processing Record 15 of Set 6 | spornoye
# Processing Record 16 of Set 6 | ancud
# Processing Record 17 of Set 6 | puerto escondido
# City not found. Skipping...
# Processing Record 18 of Set 6 | zeya
# Processing Record 19 of Set 6 | gairo
# Processing Record 20 of Set 6 | saskylakh
# Processing Record 21 of Set 6 | beringovskiy
# Processing Record 22 of Set 6 | vao
# Processing Record 23 of Set 6 | west wendover
# Processing Record 24 of Set 6 | cordoba
# Processing Record 25 of Set 6 | treinta y tres
# Processing Record 26 of Set 6 | nizwa
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | nakonde
# Processing Record 29 of Set 6 | honiara
# Processing Record 30 of Set 6 | parintins
# City not found. Skipping...
# Processing Record 31 of Set 6 | sept-iles
# Processing Record 32 of Set 6 | kankon
# Processing Record 33 of Set 6 | grindavik
# Processing Record 34 of Set 6 | husavik
# Processing Record 35 of Set 6 | chapais
# Processing Record 36 of Set 6 | flinders
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 6 | guerrero negro
# Processing Record 38 of Set 6 | shaunavon
# Processing Record 39 of Set 6 | najran
# Processing Record 40 of Set 6 | ust-kuyga
# Processing Record 41 of Set 6 | sterling
# Processing Record 42 of Set 6 | luderitz
# City not found. Skipping...
# Processing Record 43 of Set 6 | upernavik
# Processing Record 44 of Set 6 | hagersville
# Processing Record 45 of Set 6 | rio gallegos
# Processing Record 46 of Set 6 | cabo san lucas
# Processing Record 47 of Set 6 | myitkyina
# Processing Record 48 of Set 6 | hofn
# Processing Record 49 of Set 6 | newport
# Processing Record 50 of Set 6 | the valley
# Processing Record 0 of Set 7 | kilindoni
# Processing Record 1 of Set 7 | muli
# Processing Record 2 of Set 7 | moose factory
# Processing Record 3 of Set 7 | haines junction
# Processing Record 4 of Set 7 | nikolskoye
# Processing Record 5 of Set 7 | half moon bay
# Processing Record 6 of Set 7 | nanton
# Processing Record 7 of Set 7 | auburn
# Processing Record 8 of Set 7 | coihaique
# Processing Record 9 of Set 7 | camana
# Processing Record 10 of Set 7 | sisimiut
# Processing Record 11 of Set 7 | kysyl-syr
# Processing Record 12 of Set 7 | terenos
# Processing Record 13 of Set 7 | chuy
# Processing Record 14 of Set 7 | atasu
# Processing Record 15 of Set 7 | samarai
# Processing Record 16 of Set 7 | samana
# Processing Record 17 of Set 7 | igrim
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | pierre
# Processing Record 20 of Set 7 | xichang
# Processing Record 21 of Set 7 | lyuban
# Processing Record 22 of Set 7 | marzuq
# Processing Record 23 of Set 7 | maniitsoq
# Processing Record 24 of Set 7 | ewa beach
# Processing Record 25 of Set 7 | baneasa
# City not found. Skipping...
# Processing Record 26 of Set 7 | ossora
# Processing Record 27 of Set 7 | kahului
# Processing Record 28 of Set 7 | vardo
# City not found. Skipping...
# Processing Record 29 of Set 7 | port said
# Processing Record 30 of Set 7 | betong
# Processing Record 31 of Set 7 | puerto carreno
# Processing Record 32 of Set 7 | ranong
# City not found. Skipping...
# Processing Record 33 of Set 7 | yatou
# City not found. Skipping...
# Processing Record 34 of Set 7 | cap-chat
# Processing Record 35 of Set 7 | tessalit
# Processing Record 36 of Set 7 | winslow
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | ojinaga
# Processing Record 39 of Set 7 | margate
# Processing Record 40 of Set 7 | mamallapuram
# Processing Record 41 of Set 7 | inhambane
# Processing Record 42 of Set 7 | itarema
# Processing Record 43 of Set 7 | tupiza
# Processing Record 44 of Set 7 | koutiala
# Processing Record 45 of Set 7 | porto novo
# Processing Record 46 of Set 7 | pochutla
# Processing Record 47 of Set 7 | saint-augustin
# City not found. Skipping...
# Processing Record 48 of Set 7 | kampene
# City not found. Skipping...
# Processing Record 49 of Set 7 | mucurapo
# Processing Record 50 of Set 7 | wencheng
# Processing Record 0 of Set 8 | corinth
# Processing Record 1 of Set 8 | jawhar
# Processing Record 2 of Set 8 | san andres
# Processing Record 3 of Set 8 | henties bay
# Processing Record 4 of Set 8 | gurupa
# Processing Record 5 of Set 8 | aguas belas
# Processing Record 6 of Set 8 | sitka
# Processing Record 7 of Set 8 | lasa
# Processing Record 8 of Set 8 | richards bay
# Processing Record 9 of Set 8 | lima
# Processing Record 10 of Set 8 | daru
# Processing Record 11 of Set 8 | san joaquin
# City not found. Skipping...
# Processing Record 12 of Set 8 | sovetskiy
# Processing Record 13 of Set 8 | pasighat
# Processing Record 14 of Set 8 | trairi
# Processing Record 15 of Set 8 | gat
# Processing Record 16 of Set 8 | russkaya polyana
# City not found. Skipping...
# Processing Record 17 of Set 8 | luwuk
# Processing Record 18 of Set 8 | wittlich
# Processing Record 19 of Set 8 | rawah
# Processing Record 20 of Set 8 | provideniya
# Processing Record 21 of Set 8 | nuuk
# Processing Record 22 of Set 8 | pervomayskoye
# Processing Record 23 of Set 8 | rocha
# Processing Record 24 of Set 8 | okhotsk
# Processing Record 25 of Set 8 | tautira
# City not found. Skipping...
# Processing Record 26 of Set 8 | la ronge
# Processing Record 27 of Set 8 | port lincoln
# Processing Record 28 of Set 8 | bereda
# Processing Record 29 of Set 8 | cabedelo
# Processing Record 30 of Set 8 | palmeira das missoes
# Processing Record 31 of Set 8 | yabucoa
# Processing Record 32 of Set 8 | almaznyy
# Processing Record 33 of Set 8 | necochea
# Processing Record 34 of Set 8 | port hedland
# Processing Record 35 of Set 8 | suzhou
# City not found. Skipping...
# Processing Record 36 of Set 8 | great bend
# Processing Record 37 of Set 8 | ilulissat
# Processing Record 38 of Set 8 | purpe
# Processing Record 39 of Set 8 | krasnyy yar
# Processing Record 40 of Set 8 | calatayud
# Processing Record 41 of Set 8 | mackenzie
# Processing Record 42 of Set 8 | pacific grove
# Processing Record 43 of Set 8 | nyurba
# City not found. Skipping...
# Processing Record 44 of Set 8 | akure
# Processing Record 45 of Set 8 | la peca
# Processing Record 46 of Set 8 | nuevo imperial
# Processing Record 47 of Set 8 | luzhou
# Processing Record 48 of Set 8 | kruisfontein
# Processing Record 49 of Set 8 | aylesbury
# Processing Record 50 of Set 8 | kautokeino
# Processing Record 0 of Set 9 | komsomolskiy
# Processing Record 1 of Set 9 | mount isa
# Processing Record 2 of Set 9 | itoman
# Processing Record 3 of Set 9 | alekseyevsk
# Processing Record 4 of Set 9 | upata
# Processing Record 5 of Set 9 | talnakh
# Processing Record 6 of Set 9 | patharia
# Processing Record 7 of Set 9 | champasak
# Processing Record 8 of Set 9 | denpasar
# Processing Record 9 of Set 9 | fort william
# Processing Record 10 of Set 9 | monroe
# City not found. Skipping...
# Processing Record 11 of Set 9 | youghal
# Processing Record 12 of Set 9 | port-cartier
# City not found. Skipping...
# Processing Record 13 of Set 9 | roald
# Processing Record 14 of Set 9 | dingle
# Processing Record 15 of Set 9 | zlobin
# Processing Record 16 of Set 9 | fairmount
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | sinnamary
# Processing Record 19 of Set 9 | tamandare
# Processing Record 20 of Set 9 | roebourne
# Processing Record 21 of Set 9 | salalah
# Processing Record 22 of Set 9 | linhares
# Processing Record 23 of Set 9 | maine-soroa
# Processing Record 24 of Set 9 | port-gentil
# Processing Record 25 of Set 9 | mecca
# Processing Record 26 of Set 9 | fortuna
# Processing Record 27 of Set 9 | filadelfia
# City not found. Skipping...
# Processing Record 28 of Set 9 | maningrida
# Processing Record 29 of Set 9 | jacareacanga
# Processing Record 30 of Set 9 | ust-ilimsk
# Processing Record 31 of Set 9 | havelock
# Processing Record 32 of Set 9 | aklavik
# Processing Record 33 of Set 9 | naze
# Processing Record 34 of Set 9 | kavieng
# Processing Record 35 of Set 9 | nabire
# Processing Record 36 of Set 9 | tumut
# Processing Record 37 of Set 9 | porangatu
# Processing Record 38 of Set 9 | verkhnevilyuysk
# Processing Record 39 of Set 9 | tura
# Processing Record 40 of Set 9 | mitsamiouli
# Processing Record 41 of Set 9 | bluefields
# Processing Record 42 of Set 9 | tual
# Processing Record 43 of Set 9 | yaan
# Processing Record 44 of Set 9 | zhezkazgan
# Processing Record 45 of Set 9 | khani
# Processing Record 46 of Set 9 | mumford
# Processing Record 47 of Set 9 | mana
# Processing Record 48 of Set 9 | soto la marina
# Processing Record 49 of Set 9 | vung tau
# Processing Record 50 of Set 9 | moree
# City not found. Skipping...
# Processing Record 0 of Set 10 | ornskoldsvik
# Processing Record 1 of Set 10 | bathsheba
# City not found. Skipping...
# Processing Record 2 of Set 10 | banda aceh
# City not found. Skipping...
# Processing Record 3 of Set 10 | paamiut
# Processing Record 4 of Set 10 | ise
# Processing Record 5 of Set 10 | humaita
# Processing Record 6 of Set 10 | deputatskiy
# Processing Record 7 of Set 10 | cayenne
# Processing Record 8 of Set 10 | licata
# Processing Record 9 of Set 10 | latung
# Processing Record 10 of Set 10 | erzin
# Processing Record 11 of Set 10 | amapa
# Processing Record 12 of Set 10 | mastic beach
# Processing Record 13 of Set 10 | kapit
# Processing Record 14 of Set 10 | bilibino
# Processing Record 15 of Set 10 | fort nelson
# Processing Record 16 of Set 10 | gotsu
# Processing Record 17 of Set 10 | airai
# Processing Record 18 of Set 10 | sabinopolis
# Processing Record 19 of Set 10 | khor
# Processing Record 20 of Set 10 | coahuayana
# Processing Record 21 of Set 10 | atherton
# Processing Record 22 of Set 10 | tres palos
# Processing Record 23 of Set 10 | hede
# Processing Record 24 of Set 10 | amalapuram
# Processing Record 25 of Set 10 | north bend
# Processing Record 26 of Set 10 | tumen
# City not found. Skipping...
# Processing Record 27 of Set 10 | kloulklubed
# Processing Record 28 of Set 10 | tumwater
# Processing Record 29 of Set 10 | ostrovnoy
# Processing Record 30 of Set 10 | boca do acre
# Processing Record 31 of Set 10 | isiolo
# Processing Record 32 of Set 10 | olafsvik
# Processing Record 33 of Set 10 | chimore
# Processing Record 34 of Set 10 | labuhan
# Processing Record 35 of Set 10 | maiduguri
# Processing Record 36 of Set 10 | vila do maio
# Processing Record 37 of Set 10 | mangrol
# Processing Record 38 of Set 10 | talara
# Processing Record 39 of Set 10 | panguna
# Processing Record 40 of Set 10 | mzimba
# Processing Record 41 of Set 10 | port macquarie
# Processing Record 42 of Set 10 | abu samrah
# Processing Record 43 of Set 10 | kupang
# Processing Record 44 of Set 10 | washougal
# Processing Record 45 of Set 10 | kavaratti
# Processing Record 46 of Set 10 | tazovskiy
# Processing Record 47 of Set 10 | snasa
# Processing Record 48 of Set 10 | sinjar
# Processing Record 49 of Set 10 | black river
# Processing Record 50 of Set 10 | little current
# Processing Record 0 of Set 11 | taywarah
# Processing Record 1 of Set 11 | coos bay
# Processing Record 2 of Set 11 | harlingen
# Processing Record 3 of Set 11 | baiao
# Processing Record 4 of Set 11 | bubaque
# Processing Record 5 of Set 11 | luis correia
# Processing Record 6 of Set 11 | sobolevo
# Processing Record 7 of Set 11 | calvinia
# Processing Record 8 of Set 11 | champerico
# Processing Record 9 of Set 11 | capitao poco
# Processing Record 10 of Set 11 | shimoda
# Processing Record 11 of Set 11 | blairmore
# Processing Record 12 of Set 11 | nanzhang
# Processing Record 13 of Set 11 | puerto suarez
# Processing Record 14 of Set 11 | ongandjera
# Processing Record 15 of Set 11 | alihe
# Processing Record 16 of Set 11 | bokoro
# City not found. Skipping...
# Processing Record 17 of Set 11 | jibuti
# Processing Record 18 of Set 11 | brigantine
# Processing Record 19 of Set 11 | sao gabriel da cachoeira
# City not found. Skipping...
# Processing Record 20 of Set 11 | brownsville
# City not found. Skipping...
# Processing Record 21 of Set 11 | matamoros
# Processing Record 22 of Set 11 | stornoway
# Processing Record 23 of Set 11 | thinadhoo
# Processing Record 24 of Set 11 | rundu
# Processing Record 25 of Set 11 | maralal
# Processing Record 26 of Set 11 | manzhouli
# Processing Record 27 of Set 11 | hvolsvollur
# Processing Record 28 of Set 11 | vanimo
# Processing Record 29 of Set 11 | san cristobal
# Processing Record 30 of Set 11 | portland
# City not found. Skipping...
# Processing Record 31 of Set 11 | willowmore
# Processing Record 32 of Set 11 | vestmanna
# Processing Record 33 of Set 11 | bud
# Processing Record 34 of Set 11 | grand-santi
# Processing Record 35 of Set 11 | barguzin
# Processing Record 36 of Set 11 | cap malheureux
# Processing Record 37 of Set 11 | shubarkuduk
# Processing Record 38 of Set 11 | waldshut-tiengen
# Processing Record 39 of Set 11 | bijar
# Processing Record 40 of Set 11 | maridi
# Processing Record 41 of Set 11 | batemans bay
# Processing Record 42 of Set 11 | kieta
# Processing Record 43 of Set 11 | alghero
# Processing Record 44 of Set 11 | buala
# Processing Record 45 of Set 11 | saurimo
# Processing Record 46 of Set 11 | oranjemund
# Processing Record 47 of Set 11 | amahai
# Processing Record 48 of Set 11 | worksop
# Processing Record 49 of Set 11 | road town
# Processing Record 50 of Set 11 | dwarka
# Processing Record 0 of Set 12 | yabrud
# Processing Record 1 of Set 12 | yar-sale
# Processing Record 2 of Set 12 | khandbari
# Processing Record 3 of Set 12 | pizarro
# Processing Record 4 of Set 12 | beni
# Processing Record 5 of Set 12 | abancay
# Processing Record 6 of Set 12 | byron bay
# Processing Record 7 of Set 12 | coolum beach
# Processing Record 8 of Set 12 | praia da vitoria
# Processing Record 9 of Set 12 | elat
# Processing Record 10 of Set 12 | zhangjiakou
# Processing Record 11 of Set 12 | arkhangelsk
# Processing Record 12 of Set 12 | gisborne
# Processing Record 13 of Set 12 | middelburg
# Processing Record 14 of Set 12 | hovd
# Processing Record 15 of Set 12 | macenta
# Processing Record 16 of Set 12 | gao
# Processing Record 17 of Set 12 | nanortalik
# City not found. Skipping...
# Processing Record 18 of Set 12 | neyvo-shaytanskiy
# Processing Record 19 of Set 12 | coihueco
# Processing Record 20 of Set 12 | vigrestad
# Processing Record 21 of Set 12 | alice springs
# Processing Record 22 of Set 12 | kayerkan
# Processing Record 23 of Set 12 | dalby
# Processing Record 24 of Set 12 | odweyne
# Processing Record 25 of Set 12 | chaplygin
# Processing Record 26 of Set 12 | impfondo
# Processing Record 27 of Set 12 | san ramon
# Processing Record 28 of Set 12 | zaria
# Processing Record 29 of Set 12 | north platte
# Processing Record 30 of Set 12 | tel aviv-yafo
# City not found. Skipping...
# Processing Record 31 of Set 12 | bandarbeyla
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# first create the dataframe for the list of responses and display
city_weather_df = pd.DataFrame({'City': city_name, 
                                  'Latitude': lat, 
                                  'Longitude': lon, 
                                  'Max Temp': max_temp, 
                                  'Humidity': humidity, 
                                  'Cloudiness': cloudiness, 
                                  'Wind Speed': wind_speed, 
                                  'Date': dates})
city_weather_df.head()

#second save and export dataframe to final outputs folder

#city_weather_df.to_csv("Final_Outputs/cities_final.csv", index = False)
# Out:
#             City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0       Araouane     18.90      -3.53     88.88        12         100
# 1        Rikitea    -23.12    -134.97     72.32        82          70
# 2    Nowy Tomyśl     52.32      16.13     59.00        93         100
# 3       Paracuru     -3.41     -39.03     82.00        76          31
# 4  Leningradskiy     69.38     178.42     15.82        84         100
#
#    Wind Speed        Date
# 0        9.01  1604338267
# 1       21.05  1604338320
# 2        2.24  1604338083
# 3       20.00  1604338321
# 4        4.27  1604338321

# %% [markdown]
# ### Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# check for cities with humidity greater than 100%: no cities over 100 humidity ---- > move on
humidity_check = city_weather_df.loc[city_weather_df['Humidity'] > 100,:]
humidity_check
# Out:
# Empty DataFrame
# Columns: [City, Latitude, Longitude, Max Temp, Humidity, Cloudiness, Wind Speed, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(15,8))
todayDate = arrow.now().format('MM/DD/YY')
plt.scatter(city_weather_df['Latitude'], city_weather_df['Max Temp'], s=100, c='midnightblue')
plt.title(f'City Latitude vs. Max Temperature ({todayDate})',fontsize =20)
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Max Temperature (F)',fontsize =15)
plt.grid(color='royalblue', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(15,8))
plt.scatter(city_weather_df['Latitude'], city_weather_df['Humidity'], s=100, c='yellowgreen')
plt.title(f'City Latitude vs. Humidity ({todayDate})',fontsize =20)
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Humidity (%)',fontsize =15)
plt.grid(color='seagreen', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(15,8))
plt.scatter(city_weather_df['Latitude'], city_weather_df['Cloudiness'], s=100, c='orange')
plt.title(f'City Latitude vs. Cloudiness ({todayDate})',fontsize =20)
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Cloudiness (%)',fontsize =15)
plt.grid(color='lightcoral', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(15,8))
plt.scatter(city_weather_df['Latitude'], city_weather_df['Wind Speed'], s=100, c='crimson')
plt.title(f'City Latitude vs. Wind Speed ({todayDate})',fontsize =20)
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Wind Speed (mph)',fontsize =15)
plt.grid(color='maroon', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ###  Northern Hemisphere - Correlation Coefficient for Max Temp vs. Latitude

# %%
# get the latitudes for northern hemisphere and southern hemisphere
northern_hemisphere_df = city_weather_df.loc[city_weather_df['Latitude'] >= 0,:]
southern_hemisphere_df = city_weather_df.loc[city_weather_df['Latitude'] < 0,:]

# Calculate the correlation coefficient to see the cooralation between max temperature and latitude in the northern hemisphere
correlation_coefficient = round(sts.pearsonr(northern_hemisphere_df['Latitude'], northern_hemisphere_df['Max Temp'])[0],4)

print(f'The correlation coefficient for max temperature and latitude is: {correlation_coefficient}\n')
# Out:
# The correlation coefficient for max temperature and latitude is: -0.8605

# %% [markdown]
# ###  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate the linear regression for max temperature and latitude in the northern hemisphere

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(northern_hemisphere_df['Latitude'], northern_hemisphere_df['Max Temp'])
regress_values = slope * northern_hemisphere_df['Latitude'] + intercept
equation = 'y= ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2))

plt.figure(figsize=(15,8))
plt.scatter(northern_hemisphere_df['Latitude'], northern_hemisphere_df['Max Temp'], s=50, c='midnightblue')
plt.plot(northern_hemisphere_df['Latitude'], regress_values, color='red')
plt.title('Max Temperature vs. Latitude (Northern Hemisphere)',fontsize =20)
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Max Temp',fontsize =15)
plt.annotate(equation, xy=(5, 50), fontsize=20, color='red')
print(f'the r square value is: {rvalue}\n')
plt.show()
# Out:
# the r square value is: -0.8605267415804564

# %% [markdown]
# ###  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate the linear regression for max temperature and latitude in the southern hemisphere

(slope, intercept, rvalue, pvalue, stderr) = sts.linregress(southern_hemisphere_df['Latitude'], southern_hemisphere_df['Max Temp'])
regress_values = slope * southern_hemisphere_df['Latitude'] + intercept
equation = 'y= ' + str(round(slope, 2)) + 'x + ' + str(round(intercept, 2))

plt.figure(figsize=(15,8))
plt.scatter(southern_hemisphere_df['Latitude'], southern_hemisphere_df['Max Temp'], s=50, c='midnightblue')
plt.plot(southern_hemisphere_df['Latitude'], regress_values, color='red')
plt.title('Max Temperature vs. Latitude (Southern Hemisphere)',fontsize =20)
plt.xlabel('Latitude',fontsize =15)
plt.ylabel('Max Temp',fontsize =15)
plt.annotate(equation, xy=(-20, 55), fontsize=20, color='red')
print(f'the r square value is: {rvalue}\n')
plt.show()
# Out:
# the r square value is: 0.727525819638118
