# %% [markdown]
# # WeatherPy Main Workfile

# %% [markdown]
# ## Initial identification

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

api_key = weather_api_key
#print(api_key)
len(cities)
# Out:
# 617

# %% [markdown]
# ## Perform API Calls

# %%
# parameters

url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'metric'
query_url = f'{url}appid={api_key}&units={units}&q='

# %%
# list names for dataframe
city_name = []
cloudiness = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

# %%
# counters to store record counts and sets of 50 counts
record_count = 0
set_count = 1

# %%
# loop through list of random cities

for index, city in enumerate(cities):
    
    time.sleep(1)    
    
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        if record_count > 49:
            record_count = 0
            set_count += 1
        else:
            record_count += 1
        print(f'Beginning Data Retrieval')
        print('-------------------------------')
        print(f"Processing Record {record_count} | Set {set_count} : {city}")
        print('-------------------------------')
        print('Data Retrieval Complete ')
        print('-------------------------------')
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Processing Record 1 | Set 1 : hobart
# Processing Record 2 | Set 1 : carnarvon
# Processing Record 3 | Set 1 : moree
# Processing Record 4 | Set 1 : lincoln
# Processing Record 5 | Set 1 : greensburg
# Processing Record 6 | Set 1 : georgetown
# Processing Record 7 | Set 1 : shingu
# Processing Record 8 | Set 1 : geraldton
# Processing Record 9 | Set 1 : busselton
# Processing Record 10 | Set 1 : yellowknife
# Processing Record 11 | Set 1 : raudeberg
# Processing Record 12 | Set 1 : punta arenas
# Processing Record 13 | Set 1 : kushima
# Processing Record 14 | Set 1 : hilo
# Processing Record 15 | Set 1 : nome
# Processing Record 16 | Set 1 : yatou
# Processing Record 17 | Set 1 : clyde river
# Processing Record 18 | Set 1 : dire
# Processing Record 19 | Set 1 : atuona
# Processing Record 20 | Set 1 : tomatlan
# Processing Record 21 | Set 1 : tuatapere
# Processing Record 22 | Set 1 : sarankhola
# Processing Record 23 | Set 1 : san patricio
# Processing Record 24 | Set 1 : port hardy
# Processing Record 25 | Set 1 : balabac
# Processing Record 26 | Set 1 : marsh harbour
# Processing Record 27 | Set 1 : galesong
# City not found. Skipping...
# Processing Record 28 | Set 1 : bluff
# City not found. Skipping...
# Processing Record 29 | Set 1 : lompoc
# Processing Record 30 | Set 1 : albany
# Processing Record 31 | Set 1 : kahului
# Processing Record 32 | Set 1 : kodiak
# Processing Record 33 | Set 1 : puerto ayora
# Processing Record 34 | Set 1 : nanortalik
# Processing Record 35 | Set 1 : vaini
# Processing Record 36 | Set 1 : port blair
# Processing Record 37 | Set 1 : luderitz
# Processing Record 38 | Set 1 : santa maria
# Processing Record 39 | Set 1 : jamestown
# Processing Record 40 | Set 1 : torbay
# Processing Record 41 | Set 1 : chokurdakh
# Processing Record 42 | Set 1 : port alfred
# Processing Record 43 | Set 1 : arraial do cabo
# Processing Record 44 | Set 1 : hermanus
# Processing Record 45 | Set 1 : vila franca do campo
# Processing Record 46 | Set 1 : road town
# Processing Record 47 | Set 1 : mongo
# Processing Record 48 | Set 1 : qaanaaq
# Processing Record 49 | Set 1 : khatanga
# Processing Record 50 | Set 1 : kavieng
# Processing Record 0 | Set 2 : saint-philippe
# Processing Record 1 | Set 2 : roxana
# Processing Record 2 | Set 2 : juegang
# City not found. Skipping...
# Processing Record 3 | Set 2 : ushuaia
# Processing Record 4 | Set 2 : ugoofaaru
# Processing Record 5 | Set 2 : atar
# Processing Record 6 | Set 2 : ndjole
# Processing Record 7 | Set 2 : half moon bay
# Processing Record 8 | Set 2 : montecristi
# Processing Record 9 | Set 2 : lasa
# City not found. Skipping...
# Processing Record 10 | Set 2 : blyznyuky
# Processing Record 11 | Set 2 : coron
# Processing Record 12 | Set 2 : tasiilaq
# Processing Record 13 | Set 2 : bilma
# Processing Record 14 | Set 2 : doha
# Processing Record 15 | Set 2 : mosquera
# Processing Record 16 | Set 2 : iquique
# City not found. Skipping...
# Processing Record 17 | Set 2 : codrington
# Processing Record 18 | Set 2 : saint-pierre
# Processing Record 19 | Set 2 : aasiaat
# Processing Record 20 | Set 2 : paamiut
# Processing Record 21 | Set 2 : thinadhoo
# Processing Record 22 | Set 2 : airai
# Processing Record 23 | Set 2 : chazuta
# Processing Record 24 | Set 2 : mataura
# Processing Record 25 | Set 2 : coihaique
# Processing Record 26 | Set 2 : prescott
# Processing Record 27 | Set 2 : kaitangata
# Processing Record 28 | Set 2 : rikitea
# Processing Record 29 | Set 2 : victoria
# Processing Record 30 | Set 2 : east london
# Processing Record 31 | Set 2 : yarim
# City not found. Skipping...
# Processing Record 32 | Set 2 : scarborough
# Processing Record 33 | Set 2 : glenwood springs
# Processing Record 34 | Set 2 : wajima
# Processing Record 35 | Set 2 : hamilton
# Processing Record 36 | Set 2 : nattam
# Processing Record 37 | Set 2 : butaritari
# Processing Record 38 | Set 2 : cape town
# Processing Record 39 | Set 2 : sokoni
# Processing Record 40 | Set 2 : thompson
# Processing Record 41 | Set 2 : hithadhoo
# Processing Record 42 | Set 2 : kozluk
# Processing Record 43 | Set 2 : kilindoni
# Processing Record 44 | Set 2 : port hedland
# Processing Record 45 | Set 2 : hasaki
# City not found. Skipping...
# Processing Record 46 | Set 2 : amahai
# Processing Record 47 | Set 2 : maxixe
# Processing Record 48 | Set 2 : beringovskiy
# Processing Record 49 | Set 2 : knysna
# Processing Record 50 | Set 2 : veraval
# Processing Record 0 | Set 3 : bredasdorp
# Processing Record 1 | Set 3 : mgandu
# Processing Record 2 | Set 3 : cabo san lucas
# Processing Record 3 | Set 3 : harper
# Processing Record 4 | Set 3 : san jose
# Processing Record 5 | Set 3 : safaga
# Processing Record 6 | Set 3 : port elizabeth
# Processing Record 7 | Set 3 : vysokogornyy
# City not found. Skipping...
# Processing Record 8 | Set 3 : lebu
# Processing Record 9 | Set 3 : bonavista
# Processing Record 10 | Set 3 : new norfolk
# Processing Record 11 | Set 3 : prince rupert
# Processing Record 12 | Set 3 : padang
# City not found. Skipping...
# Processing Record 13 | Set 3 : abatskoye
# Processing Record 14 | Set 3 : yumen
# Processing Record 15 | Set 3 : reconquista
# Processing Record 16 | Set 3 : amalapuram
# Processing Record 17 | Set 3 : fazilka
# Processing Record 18 | Set 3 : kupang
# City not found. Skipping...
# Processing Record 19 | Set 3 : marzuq
# Processing Record 20 | Set 3 : tuktoyaktuk
# Processing Record 21 | Set 3 : fortuna
# Processing Record 22 | Set 3 : berbera
# Processing Record 23 | Set 3 : waingapu
# Processing Record 24 | Set 3 : kibre mengist
# Processing Record 25 | Set 3 : ponta do sol
# City not found. Skipping...
# Processing Record 26 | Set 3 : imeni poliny osipenko
# City not found. Skipping...
# Processing Record 27 | Set 3 : kijang
# Processing Record 28 | Set 3 : pevek
# Processing Record 29 | Set 3 : nikolskoye
# Processing Record 30 | Set 3 : cherskiy
# Processing Record 31 | Set 3 : fairbanks
# Processing Record 32 | Set 3 : yangambi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 | Set 3 : ambatondrazaka
# Processing Record 34 | Set 3 : asau
# Processing Record 35 | Set 3 : tessalit
# Processing Record 36 | Set 3 : tabou
# Processing Record 37 | Set 3 : alofi
# Processing Record 38 | Set 3 : ahuimanu
# Processing Record 39 | Set 3 : kapaa
# Processing Record 40 | Set 3 : komsomolskiy
# Processing Record 41 | Set 3 : arlit
# Processing Record 42 | Set 3 : richards bay
# Processing Record 43 | Set 3 : eureka
# Processing Record 44 | Set 3 : quatre cocos
# City not found. Skipping...
# Processing Record 45 | Set 3 : lenoir city
# Processing Record 46 | Set 3 : buin
# Processing Record 47 | Set 3 : talnakh
# Processing Record 48 | Set 3 : kholbon
# City not found. Skipping...
# Processing Record 49 | Set 3 : zachary
# Processing Record 50 | Set 3 : christchurch
# Processing Record 0 | Set 4 : kutum
# Processing Record 1 | Set 4 : san carlos de bariloche
# Processing Record 2 | Set 4 : rincon
# Processing Record 3 | Set 4 : phayakkhaphum phisai
# Processing Record 4 | Set 4 : lorengau
# Processing Record 5 | Set 4 : raton
# Processing Record 6 | Set 4 : springbok
# Processing Record 7 | Set 4 : tiksi
# Processing Record 8 | Set 4 : ostersund
# Processing Record 9 | Set 4 : straumen
# Processing Record 10 | Set 4 : conde
# Processing Record 11 | Set 4 : castro
# Processing Record 12 | Set 4 : bandarbeyla
# Processing Record 13 | Set 4 : joshimath
# Processing Record 14 | Set 4 : grindavik
# Processing Record 15 | Set 4 : libertador general san martin
# Processing Record 16 | Set 4 : belyy yar
# Processing Record 17 | Set 4 : namatanai
# Processing Record 18 | Set 4 : perigueux
# Processing Record 19 | Set 4 : saskylakh
# Processing Record 20 | Set 4 : upernavik
# Processing Record 21 | Set 4 : pedasi
# City not found. Skipping...
# Processing Record 22 | Set 4 : san cristobal
# Processing Record 23 | Set 4 : pedernales
# Processing Record 24 | Set 4 : drumnadrochit
# Processing Record 25 | Set 4 : high rock
# Processing Record 26 | Set 4 : greystones
# Processing Record 27 | Set 4 : mayor pablo lagerenza
# Processing Record 28 | Set 4 : adrar
# Processing Record 29 | Set 4 : puerto colombia
# Processing Record 30 | Set 4 : avarua
# Processing Record 31 | Set 4 : rocha
# Processing Record 32 | Set 4 : svetlogorsk
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-8a9269fb3ca1> in <module>
#       3 for index, city in enumerate(cities):
#       4
# ----> 5     time.sleep(2)
#       6
#       7     try:
#
# KeyboardInterrupt:
