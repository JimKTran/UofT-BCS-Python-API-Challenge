# %% [markdown]
# # WeatherPy Main Workfile

# %% [markdown]
# ## Initial identification

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

api_key = weather_api_key
#print(api_key)
len(cities)
# Out:
# 606

# %% [markdown]
# ## Perform API Calls

# %%
# parameters

url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'metric'
query_url = f'{url}appid={api_key}&units={units}&q='

# %%
# list names for dataframe
city_name = []
cloudiness = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

# %%
# counters to store record counts and sets of 50 counts
record_count = 0
set_count = 1

# %%
# loop through list of random cities

print(f'Beginning Data Retrieval')
print('-------------------------------')

for index, city in enumerate(cities):
    
    time.sleep(1) # Add a one second interval between queries to stay within API query limits   
    

    
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        if record_count > 49:
            record_count = 0
            set_count += 1
        else:
            record_count += 1

        print(f"Processing Record {record_count} of Set {set_count} | {city}")
  
    except(KeyError, IndexError):
        
        print("City not found. Skipping...")
        
print('-------------------------------')
print('Data Retrieval Complete ')
print('-------------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | grand gaube
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | abalak
# Processing Record 6 of Set 1 | saint-augustin
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | saint anthony
# Processing Record 9 of Set 1 | murgab
# Processing Record 10 of Set 1 | nanlong
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | ondangwa
# Processing Record 13 of Set 1 | la ronge
# Processing Record 14 of Set 1 | jhabua
# Processing Record 15 of Set 1 | dong hoi
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | dingle
# Processing Record 21 of Set 1 | la asuncion
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | alekseyevskoye
# Processing Record 24 of Set 1 | chokurdakh
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | chiang khong
# Processing Record 27 of Set 1 | leningradskiy
# Processing Record 28 of Set 1 | labuhan
# Processing Record 29 of Set 1 | lasa
# Processing Record 30 of Set 1 | sept-iles
# Processing Record 31 of Set 1 | mehamn
# Processing Record 32 of Set 1 | kavieng
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | barabai
# Processing Record 35 of Set 1 | panaba
# Processing Record 36 of Set 1 | lahaina
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | camocim
# Processing Record 40 of Set 1 | sangar
# Processing Record 41 of Set 1 | rocha
# Processing Record 42 of Set 1 | angoche
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | chuy
# Processing Record 45 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | parambu
# Processing Record 49 of Set 1 | irricana
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 0 of Set 2 | fare
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | zhezkazgan
# Processing Record 3 of Set 2 | iralaya
# Processing Record 4 of Set 2 | qaqortoq
# Processing Record 5 of Set 2 | sorland
# Processing Record 6 of Set 2 | arya
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | rikitea
# City not found. Skipping...
# Processing Record 9 of Set 2 | benxi
# Processing Record 10 of Set 2 | khowai
# Processing Record 11 of Set 2 | touros
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | bako
# Processing Record 15 of Set 2 | antsohihy
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | nikolskoye
# Processing Record 19 of Set 2 | tamiahua
# Processing Record 20 of Set 2 | okha
# City not found. Skipping...
# Processing Record 21 of Set 2 | katsuura
# City not found. Skipping...
# Processing Record 22 of Set 2 | georgetown
# City not found. Skipping...
# Processing Record 23 of Set 2 | nautla
# Processing Record 24 of Set 2 | razole
# Processing Record 25 of Set 2 | santa marta
# Processing Record 26 of Set 2 | nanortalik
# City not found. Skipping...
# Processing Record 27 of Set 2 | huarmey
# Processing Record 28 of Set 2 | daru
# Processing Record 29 of Set 2 | victor harbor
# Processing Record 30 of Set 2 | sinnamary
# Processing Record 31 of Set 2 | northam
# Processing Record 32 of Set 2 | ruidoso
# Processing Record 33 of Set 2 | avarua
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | vardo
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | airai
# City not found. Skipping...
# Processing Record 38 of Set 2 | carmelo
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | saskylakh
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | cayenne
# Processing Record 44 of Set 2 | narsaq
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | aitape
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | qiongshan
# Processing Record 49 of Set 2 | santa maria do para
# Processing Record 50 of Set 2 | lebu
# Processing Record 0 of Set 3 | flin flon
# Processing Record 1 of Set 3 | san cristobal
# Processing Record 2 of Set 3 | longyearbyen
# Processing Record 3 of Set 3 | marsh harbour
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | port hardy
# Processing Record 6 of Set 3 | yar-sale
# Processing Record 7 of Set 3 | riyadh
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | san jose
# Processing Record 10 of Set 3 | pochutla
# Processing Record 11 of Set 3 | henties bay
# Processing Record 12 of Set 3 | nome
# City not found. Skipping...
# Processing Record 13 of Set 3 | palmer
# Processing Record 14 of Set 3 | lancaster
# Processing Record 15 of Set 3 | russellville
# Processing Record 16 of Set 3 | quatre cocos
# Processing Record 17 of Set 3 | balkhash
# City not found. Skipping...
# Processing Record 18 of Set 3 | kahului
# City not found. Skipping...
# Processing Record 19 of Set 3 | iqaluit
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | lamar
# Processing Record 22 of Set 3 | pangnirtung
# Processing Record 23 of Set 3 | ljungby
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | honiara
# Processing Record 26 of Set 3 | lodja
# Processing Record 27 of Set 3 | tuatapere
# City not found. Skipping...
# Processing Record 28 of Set 3 | ostrovnoy
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | baneh
# Processing Record 31 of Set 3 | leh
# Processing Record 32 of Set 3 | beloha
# Processing Record 33 of Set 3 | salto del guaira
# Processing Record 34 of Set 3 | tiznit
# Processing Record 35 of Set 3 | tautira
# Processing Record 36 of Set 3 | wamba
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | hithadhoo
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | alta floresta
# Processing Record 41 of Set 3 | ode
# Processing Record 42 of Set 3 | prestea
# Processing Record 43 of Set 3 | claye-souilly
# Processing Record 44 of Set 3 | monteagudo
# Processing Record 45 of Set 3 | coquimbo
# City not found. Skipping...
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | pangai
# Processing Record 48 of Set 3 | loralai
# Processing Record 49 of Set 3 | dauphin
# Processing Record 50 of Set 3 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 0 of Set 4 | belyy yar
# Processing Record 1 of Set 4 | taltal
# Processing Record 2 of Set 4 | victoria
# Processing Record 3 of Set 4 | nelson bay
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | okhotsk
# City not found. Skipping...
# Processing Record 6 of Set 4 | buchanan
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | fengrun
# Processing Record 9 of Set 4 | saint-junien
# Processing Record 10 of Set 4 | curaca
# Processing Record 11 of Set 4 | alofi
# Processing Record 12 of Set 4 | bengkulu
# Processing Record 13 of Set 4 | moron
# Processing Record 14 of Set 4 | izazi
# Processing Record 15 of Set 4 | el obraje
# Processing Record 16 of Set 4 | vao
# Processing Record 17 of Set 4 | aklavik
# Processing Record 18 of Set 4 | hay river
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | huangmei
# Processing Record 21 of Set 4 | kidal
# Processing Record 22 of Set 4 | houston
# City not found. Skipping...
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | hami
# Processing Record 26 of Set 4 | clyde river
# Processing Record 27 of Set 4 | emerald
# Processing Record 28 of Set 4 | quelimane
# Processing Record 29 of Set 4 | aragarcas
# Processing Record 30 of Set 4 | manggar
# Processing Record 31 of Set 4 | tazmalt
# Processing Record 32 of Set 4 | el fuerte
# Processing Record 33 of Set 4 | lianzhou
# Processing Record 34 of Set 4 | lae
# Processing Record 35 of Set 4 | oranjemund
# Processing Record 36 of Set 4 | prachin buri
# Processing Record 37 of Set 4 | nata
# City not found. Skipping...
# Processing Record 38 of Set 4 | boffa
# Processing Record 39 of Set 4 | turukhansk
# Processing Record 40 of Set 4 | kaitangata
# City not found. Skipping...
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | waingapu
# City not found. Skipping...
# Processing Record 43 of Set 4 | tazovskiy
# Processing Record 44 of Set 4 | halifax
# Processing Record 45 of Set 4 | nouakchott
# Processing Record 46 of Set 4 | kieta
# Processing Record 47 of Set 4 | yumen
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | tessalit
# Processing Record 50 of Set 4 | sao filipe
# Processing Record 0 of Set 5 | san quintin
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | acarau
# Processing Record 4 of Set 5 | villa carlos paz
# Processing Record 5 of Set 5 | boves
# Processing Record 6 of Set 5 | cidreira
# City not found. Skipping...
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | bima
# Processing Record 9 of Set 5 | mackay
# Processing Record 10 of Set 5 | at-bashi
# Processing Record 11 of Set 5 | mount gambier
# Processing Record 12 of Set 5 | los llanos de aridane
# Processing Record 13 of Set 5 | ajaccio
# Processing Record 14 of Set 5 | maldonado
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | geraldton
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | kungurtug
# Processing Record 20 of Set 5 | hibbing
# Processing Record 21 of Set 5 | novyy urengoy
# Processing Record 22 of Set 5 | olafsvik
# Processing Record 23 of Set 5 | arman
# Processing Record 24 of Set 5 | robertsport
# Processing Record 25 of Set 5 | hobyo
# Processing Record 26 of Set 5 | port lincoln
# Processing Record 27 of Set 5 | dunga bunga
# Processing Record 28 of Set 5 | puerto carreno
# Processing Record 29 of Set 5 | talcahuano
# Processing Record 30 of Set 5 | sonoita
# Processing Record 31 of Set 5 | lakes entrance
# Processing Record 32 of Set 5 | dikson
# Processing Record 33 of Set 5 | sabha
# Processing Record 34 of Set 5 | khandyga
# Processing Record 35 of Set 5 | yerbogachen
# Processing Record 36 of Set 5 | kalmunai
# Processing Record 37 of Set 5 | ourinhos
# Processing Record 38 of Set 5 | prince rupert
# Processing Record 39 of Set 5 | novouzensk
# City not found. Skipping...
# Processing Record 40 of Set 5 | buala
# Processing Record 41 of Set 5 | goderich
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | aklera
# Processing Record 44 of Set 5 | isangel
# Processing Record 45 of Set 5 | kerman
# Processing Record 46 of Set 5 | chapais
# Processing Record 47 of Set 5 | george town
# Processing Record 48 of Set 5 | saint george
# Processing Record 49 of Set 5 | san patricio
# Processing Record 50 of Set 5 | ayagoz
# Processing Record 0 of Set 6 | tocopilla
# Processing Record 1 of Set 6 | fort nelson
# City not found. Skipping...
# Processing Record 2 of Set 6 | vostok
# Processing Record 3 of Set 6 | kismayo
# Processing Record 4 of Set 6 | nogales
# Processing Record 5 of Set 6 | gamboma
# Processing Record 6 of Set 6 | pitimbu
# Processing Record 7 of Set 6 | vetlanda
# Processing Record 8 of Set 6 | sao francisco de paula
# Processing Record 9 of Set 6 | shibetsu
# Processing Record 10 of Set 6 | cockburn town
# Processing Record 11 of Set 6 | coahuayana
# Processing Record 12 of Set 6 | novosysoyevka
# Processing Record 13 of Set 6 | new norfolk
# Processing Record 14 of Set 6 | coihaique
# Processing Record 15 of Set 6 | grants pass
# Processing Record 16 of Set 6 | bethel
# Processing Record 17 of Set 6 | ranfurly
# Processing Record 18 of Set 6 | ust-kuyga
# Processing Record 19 of Set 6 | srednekolymsk
# Processing Record 20 of Set 6 | jalu
# Processing Record 21 of Set 6 | maceio
# City not found. Skipping...
# Processing Record 22 of Set 6 | limbang
# Processing Record 23 of Set 6 | axim
# Processing Record 24 of Set 6 | qaanaaq
# Processing Record 25 of Set 6 | sur
# Processing Record 26 of Set 6 | abu kamal
# Processing Record 27 of Set 6 | hovd
# Processing Record 28 of Set 6 | alice springs
# Processing Record 29 of Set 6 | harper
# Processing Record 30 of Set 6 | caravelas
# Processing Record 31 of Set 6 | pouembout
# Processing Record 32 of Set 6 | thanh hoa
# Processing Record 33 of Set 6 | plouzane
# Processing Record 34 of Set 6 | camacha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 6 | hashtrud
# Processing Record 36 of Set 6 | mercedes
# City not found. Skipping...
# Processing Record 37 of Set 6 | ketchikan
# Processing Record 38 of Set 6 | boa vista
# Processing Record 39 of Set 6 | komsomolskiy
# Processing Record 40 of Set 6 | bilibino
# Processing Record 41 of Set 6 | kizema
# Processing Record 42 of Set 6 | hualmay
# Processing Record 43 of Set 6 | ordu
# Processing Record 44 of Set 6 | glazov
# Processing Record 45 of Set 6 | ahipara
# Processing Record 46 of Set 6 | wajir
# Processing Record 47 of Set 6 | delijan
# Processing Record 48 of Set 6 | birao
# Processing Record 49 of Set 6 | svetlaya
# Processing Record 50 of Set 6 | dakar
# Processing Record 0 of Set 7 | kudeyevskiy
# Processing Record 1 of Set 7 | nuuk
# Processing Record 2 of Set 7 | podlesnoye
# Processing Record 3 of Set 7 | iwanai
# Processing Record 4 of Set 7 | hervey bay
# Processing Record 5 of Set 7 | dickinson
# City not found. Skipping...
# Processing Record 6 of Set 7 | shadrinsk
# Processing Record 7 of Set 7 | guerrero negro
# Processing Record 8 of Set 7 | kodiak
# Processing Record 9 of Set 7 | jumla
# Processing Record 10 of Set 7 | pskov
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | safranbolu
# Processing Record 13 of Set 7 | paamiut
# Processing Record 14 of Set 7 | ocos
# Processing Record 15 of Set 7 | shancheng
# Processing Record 16 of Set 7 | tigil
# Processing Record 17 of Set 7 | kota belud
# Processing Record 18 of Set 7 | kushima
# Processing Record 19 of Set 7 | el nispero
# Processing Record 20 of Set 7 | puerto cabezas
# Processing Record 21 of Set 7 | adrar
# Processing Record 22 of Set 7 | kloulklubed
# Processing Record 23 of Set 7 | mangrol
# Processing Record 24 of Set 7 | asfi
# Processing Record 25 of Set 7 | zhanaozen
# Processing Record 26 of Set 7 | sakakah
# City not found. Skipping...
# Processing Record 27 of Set 7 | quepos
# Processing Record 28 of Set 7 | menongue
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 7 | borovskoy
# Processing Record 30 of Set 7 | lenoir city
# Processing Record 31 of Set 7 | namatanai
# Processing Record 32 of Set 7 | port hedland
# Processing Record 33 of Set 7 | gubbi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 7 | road town
# Processing Record 35 of Set 7 | sharan
# Processing Record 36 of Set 7 | minas
# Processing Record 37 of Set 7 | lake city
# Processing Record 38 of Set 7 | buraydah
# Processing Record 39 of Set 7 | qadirpur ran
# Processing Record 40 of Set 7 | igurubi
# Processing Record 41 of Set 7 | meulaboh
# Processing Record 42 of Set 7 | kasamwa
# Processing Record 43 of Set 7 | den helder
# Processing Record 44 of Set 7 | am timan
# Processing Record 45 of Set 7 | te anau
# Processing Record 46 of Set 7 | mitsamiouli
# Processing Record 47 of Set 7 | beira
# Processing Record 48 of Set 7 | evensk
# Processing Record 49 of Set 7 | inverell
# Processing Record 50 of Set 7 | hasaki
# Processing Record 0 of Set 8 | norman wells
# Processing Record 1 of Set 8 | ulladulla
# Processing Record 2 of Set 8 | kirakira
# Processing Record 3 of Set 8 | machilipatnam
# Processing Record 4 of Set 8 | la palma
# Processing Record 5 of Set 8 | pathein
# City not found. Skipping...
# Processing Record 6 of Set 8 | aban
# Processing Record 7 of Set 8 | douglas
# Processing Record 8 of Set 8 | saldanha
# Processing Record 9 of Set 8 | kapit
# City not found. Skipping...
# Processing Record 10 of Set 8 | punta de piedra
# City not found. Skipping...
# Processing Record 11 of Set 8 | voyvozh
# Processing Record 12 of Set 8 | lagoa
# Processing Record 13 of Set 8 | negombo
# Processing Record 14 of Set 8 | seddon
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | novo aripuana
# City not found. Skipping...
# Processing Record 17 of Set 8 | dingzhou
# Processing Record 18 of Set 8 | biltine
# Processing Record 19 of Set 8 | galesong
# Processing Record 20 of Set 8 | tsabong
# Processing Record 21 of Set 8 | sao joao da barra
# Processing Record 22 of Set 8 | campana
# Processing Record 23 of Set 8 | manta
# Processing Record 24 of Set 8 | rulenge
# Processing Record 25 of Set 8 | tselinnoye
# Processing Record 26 of Set 8 | nikolayevsk-na-amure
# Processing Record 27 of Set 8 | buloh kasap
# Processing Record 28 of Set 8 | severo-kurilsk
# Processing Record 29 of Set 8 | balbalan
# Processing Record 30 of Set 8 | avera
# City not found. Skipping...
# Processing Record 31 of Set 8 | coracora
# City not found. Skipping...
# Processing Record 32 of Set 8 | luderitz
# Processing Record 33 of Set 8 | kotka
# Processing Record 34 of Set 8 | puerto baquerizo moreno
# Processing Record 35 of Set 8 | ariquemes
# Processing Record 36 of Set 8 | vinukonda
# Processing Record 37 of Set 8 | gisborne
# Processing Record 38 of Set 8 | sitka
# Processing Record 39 of Set 8 | souillac
# Processing Record 40 of Set 8 | lavrentiya
# Processing Record 41 of Set 8 | rabaul
# Processing Record 42 of Set 8 | hofn
# Processing Record 43 of Set 8 | superior
# Processing Record 44 of Set 8 | lima
# Processing Record 45 of Set 8 | itoman
# Processing Record 46 of Set 8 | tommot
# Processing Record 47 of Set 8 | ihosy
# Processing Record 48 of Set 8 | porto walter
# Processing Record 49 of Set 8 | port augusta
# Processing Record 50 of Set 8 | sao jose da coroa grande
# Processing Record 0 of Set 9 | westerland
# Processing Record 1 of Set 9 | fereydun kenar
# Processing Record 2 of Set 9 | quirinopolis
# Processing Record 3 of Set 9 | rozvadiv
# City not found. Skipping...
# Processing Record 4 of Set 9 | attingal
# City not found. Skipping...
# Processing Record 5 of Set 9 | monrovia
# Processing Record 6 of Set 9 | bandarbeyla
# Processing Record 7 of Set 9 | port-gentil
# Processing Record 8 of Set 9 | makakilo city
# Processing Record 9 of Set 9 | omboue
# Processing Record 10 of Set 9 | mayo
# Processing Record 11 of Set 9 | rawson
# Processing Record 12 of Set 9 | jaguarao
# Processing Record 13 of Set 9 | constitucion
# Processing Record 14 of Set 9 | atuntaqui
# Processing Record 15 of Set 9 | chimbote
# City not found. Skipping...
# Processing Record 16 of Set 9 | carauari
# Processing Record 17 of Set 9 | honningsvag
# Processing Record 18 of Set 9 | bonito
# Processing Record 19 of Set 9 | phan thiet
# Processing Record 20 of Set 9 | bardiyah
# Processing Record 21 of Set 9 | gabu
# Processing Record 22 of Set 9 | roald
# Processing Record 23 of Set 9 | matagami
# City not found. Skipping...
# Processing Record 24 of Set 9 | sabzevar
# Processing Record 25 of Set 9 | faya
# Processing Record 26 of Set 9 | da nang
# Processing Record 27 of Set 9 | ouadda
# Processing Record 28 of Set 9 | catamarca
# Processing Record 29 of Set 9 | savanur
# City not found. Skipping...
# Processing Record 30 of Set 9 | poso
# Processing Record 31 of Set 9 | bawku
# Processing Record 32 of Set 9 | deputatskiy
# Processing Record 33 of Set 9 | kijang
# Processing Record 34 of Set 9 | paka
# Processing Record 35 of Set 9 | marzuq
# Processing Record 36 of Set 9 | nakambala
# Processing Record 37 of Set 9 | griffith
# Processing Record 38 of Set 9 | udachnyy
# Processing Record 39 of Set 9 | tambacounda
# Processing Record 40 of Set 9 | conakry
# Processing Record 41 of Set 9 | calafell
# Processing Record 42 of Set 9 | wlingi
# Processing Record 43 of Set 9 | bedesa
# Processing Record 44 of Set 9 | solnechnyy
# Processing Record 45 of Set 9 | plettenberg bay
# Processing Record 46 of Set 9 | celestun
# Processing Record 47 of Set 9 | gorontalo
# Processing Record 48 of Set 9 | sibolga
# Processing Record 49 of Set 9 | akdepe
# Processing Record 50 of Set 9 | muravlenko
# Processing Record 0 of Set 10 | grass valley
# City not found. Skipping...
# Processing Record 1 of Set 10 | izvoarele
# Processing Record 2 of Set 10 | mabai
# Processing Record 3 of Set 10 | ladnun
# Processing Record 4 of Set 10 | kohtla-jarve
# Processing Record 5 of Set 10 | urucara
# Processing Record 6 of Set 10 | saint-pierre
# Processing Record 7 of Set 10 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 8 of Set 10 | poum
# Processing Record 9 of Set 10 | casambalangan
# Processing Record 10 of Set 10 | eyl
# Processing Record 11 of Set 10 | cubuk
# Processing Record 12 of Set 10 | elko
# Processing Record 13 of Set 10 | visavadar
# City not found. Skipping...
# Processing Record 14 of Set 10 | pavino
# Processing Record 15 of Set 10 | shingu
# Processing Record 16 of Set 10 | nortelandia
# Processing Record 17 of Set 10 | skelleftea
# City not found. Skipping...
# Processing Record 18 of Set 10 | qiyang
# City not found. Skipping...
# Processing Record 19 of Set 10 | korla
# Processing Record 20 of Set 10 | kinablangan
# Processing Record 21 of Set 10 | flinders
# City not found. Skipping...
# Processing Record 22 of Set 10 | luanda
# Processing Record 23 of Set 10 | comodoro rivadavia
# Processing Record 24 of Set 10 | berlevag
# City not found. Skipping...
# Processing Record 25 of Set 10 | neyshabur
# Processing Record 26 of Set 10 | boueni
# Processing Record 27 of Set 10 | pahrump
# Processing Record 28 of Set 10 | pimentel
# Processing Record 29 of Set 10 | batticaloa
# Processing Record 30 of Set 10 | ozark
# Processing Record 31 of Set 10 | naze
# Processing Record 32 of Set 10 | koslan
# Processing Record 33 of Set 10 | harlingen
# City not found. Skipping...
# Processing Record 34 of Set 10 | nicoya
# Processing Record 35 of Set 10 | mezen
# Processing Record 36 of Set 10 | yoichi
# City not found. Skipping...
# Processing Record 37 of Set 10 | chiapilla
# Processing Record 38 of Set 10 | taitung
# Processing Record 39 of Set 10 | porto novo
# Processing Record 40 of Set 10 | lebanon
# Processing Record 41 of Set 10 | babstovo
# City not found. Skipping...
# Processing Record 42 of Set 10 | sicamous
# Processing Record 43 of Set 10 | haines junction
# Processing Record 44 of Set 10 | seymchan
# Processing Record 45 of Set 10 | rosarito
# City not found. Skipping...
# Processing Record 46 of Set 10 | kamenka
# Processing Record 47 of Set 10 | manadhoo
# Processing Record 48 of Set 10 | sola
# Processing Record 49 of Set 10 | katobu
# Processing Record 50 of Set 10 | wageningen
# Processing Record 0 of Set 11 | williamsburg
# Processing Record 1 of Set 11 | fez
# Processing Record 2 of Set 11 | yagodnoye
# Processing Record 3 of Set 11 | ginda
# Processing Record 4 of Set 11 | pasni
# Processing Record 5 of Set 11 | vilyuysk
# Processing Record 6 of Set 11 | yarada
# Processing Record 7 of Set 11 | fallon
# Processing Record 8 of Set 11 | liwale
# Processing Record 9 of Set 11 | puerto del rosario
# Processing Record 10 of Set 11 | whyalla
# Processing Record 11 of Set 11 | dhuburi
# Processing Record 12 of Set 11 | mae sai
# Processing Record 13 of Set 11 | tonantins
# Processing Record 14 of Set 11 | mount isa
# Processing Record 15 of Set 11 | margate
# Processing Record 16 of Set 11 | whitianga
# Processing Record 17 of Set 11 | ikalamavony
# City not found. Skipping...
# Processing Record 18 of Set 11 | mayya
# City not found. Skipping...
# Processing Record 19 of Set 11 | shimoda
# Processing Record 20 of Set 11 | mandvi
# Processing Record 21 of Set 11 | orissaare
# Processing Record 22 of Set 11 | monte escobedo
# Processing Record 23 of Set 11 | aksu
# Processing Record 24 of Set 11 | bonavista
# Processing Record 25 of Set 11 | manzhouli
# Processing Record 26 of Set 11 | hadgaon
# Processing Record 27 of Set 11 | thyboron
# Processing Record 28 of Set 11 | kaitong
# Processing Record 29 of Set 11 | karlskoga
# Processing Record 30 of Set 11 | tambopata
# Processing Record 31 of Set 11 | soe
# Processing Record 32 of Set 11 | carinhanha
# Processing Record 33 of Set 11 | kautokeino
# Processing Record 34 of Set 11 | xining
# Processing Record 35 of Set 11 | banda aceh
# Processing Record 36 of Set 11 | gerash
# Processing Record 37 of Set 11 | nantucket
# Processing Record 38 of Set 11 | nampula
# Processing Record 39 of Set 11 | vestmannaeyjar
# Processing Record 40 of Set 11 | davila
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
